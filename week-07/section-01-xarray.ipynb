# %% [markdown]
# # xarray tutorial
# We will be following along with: https://docs.xarray.dev/en/latest/user-guide/plotting.html working through filling out this notebook together.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import xarray as xr

# %%
airtemps = xr.tutorial.open_dataset("air_temperature")
airtemps
